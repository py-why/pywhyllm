# %%
pip install dotenv

# %%
from dotenv import load_dotenv
import os

load_dotenv()

os.environ["OPENAI_API_KEY"] = '' # specify your key here

# %%
pip install pywhyllm

# %%
from pywhyllm.suggesters.augmented_model_suggester import AugmentedModelSuggester

model = AugmentedModelSuggester('gpt-4')
# Out:
# Downloading: 100%|██████████| 131M/131M [00:05<00:00, 23.3MB/s]
# File downloaded to data/causenet-precision.jsonl.bz2
# Loading CauseNet using json
# Done loading CauseNet using json
# Creating dictionary from CauseNet json data
# Done creating dictionary from CauseNet json data

# %%
result = model.suggest_pairwise_relationship("smoking", "lung cancer")
# Out:
# Best match: smoking-lung (Similarity: 0.8014)

# %%
result
# Out:
# ['smoking',
#  'lung cancer',
#  '<answer> A </answer>\n\nThe cause-and-effect relationship is more likely to be "A. smoking causes lung cancer." This is due to the widely accepted medical and scientific evidence indicating that smoking can lead to the development of several types of cancer, including lung cancer. The literature repetitively establishes a strong causal link between smoking and lung cancer due to the harmful substances in tobacco smoke. On the contrary, lung cancer cannot cause smoking as smoking is a behavior usually initiated before the onset of disease. Option C is also not likely, given the significant evidence supporting the "smoking causes lung cancer" claim. Therefore, the correct answer is A.']

# %%
result = model.suggest_pairwise_relationship("income", "exercise level")
# Out:
# No match found with similarity above 0.7 (Best similarity: 0.0472)

# %%
result
# Out:
# [None,
#  None,
#  "While it's possible that income can influence exercise level, since higher income might allow for gym memberships, personal trainers, and more free time to exercise, there isn't a direct causation. Similarly, regular exercise might lead to improved mental health and focus that could boost job performance, but it's not a direct cause of higher income. It's more accurate to say that both are influenced by a complex set of other factors like time management, access to resources, career choices, personal discipline, or even geographic location. Thus, neither A nor B represent a direct cause-and-effect relationship.\n\n<answer> C </answer>"]

# %%
result = model.suggest_pairwise_relationship("flooding", "rain")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Best match: rain-flooding (Similarity: 1.0000)

# %%
result
# Out:
# ['rain',
#  'flooding',
#  'B. Rain causes flooding. The narrative consistently shows that rain leads to flooding. When there is too much rain over a period of time, it often results in flooding. This is a natural and common cause-and-effect relationship between weather and environmental conditions.\n<answer> B </answer>']
